# %% [markdown]
# <a href="https://colab.research.google.com/github/gogilavani369/CODSOFT/blob/main/spam_sms_detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import MultinomialNB
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC

# %%
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# %%
df = pd.read_csv('/content/spam.csv', encoding='latin-1')

# %%
df = pd.read_csv('/content/spam.csv', encoding='latin-1')
df = df[['v1', 'v2']].copy()
df.columns = ['label', 'message']

# %%
df['label'] = df['label'].map({'ham': 0, 'spam': 1})

# %%
X_train, X_test, y_train, y_test = train_test_split(
    df['message'], df['label'], test_size=0.2, random_state=42
)

# %%
tfidf = TfidfVectorizer(stop_words='english')

X_train_tfidf = tfidf.fit_transform(X_train)
X_test_tfidf = tfidf.transform(X_test)

# %%
nb = MultinomialNB()
nb.fit(X_train_tfidf, y_train)
y_pred_nb = nb.predict(X_test_tfidf)
lr = LogisticRegression()
lr.fit(X_train_tfidf, y_train)
y_pred_lr = lr.predict(X_test_tfidf)

svm = SVC()
svm.fit(X_train_tfidf, y_train)
y_pred_svm = svm.predict(X_test_tfidf)

# %%
print("----- Naive Bayes -----")
print("Accuracy:", accuracy_score(y_test, y_pred_nb))
print(classification_report(y_test, y_pred_nb))

print("\n----- Logistic Regression -----")
print("Accuracy:", accuracy_score(y_test, y_pred_lr))
print(classification_report(y_test, y_pred_lr))

print("\n----- SVM -----")
print("Accuracy:", accuracy_score(y_test, y_pred_svm))
print(classification_report(y_test, y_pred_svm))
# Out:
# ----- Naive Bayes -----
# Accuracy: 0.9668161434977578
#               precision    recall  f1-score   support
#
#          ham       0.96      1.00      0.98       965
#         spam       1.00      0.75      0.86       150
#
#     accuracy                           0.97      1115
#    macro avg       0.98      0.88      0.92      1115
# weighted avg       0.97      0.97      0.96      1115
#
#
# ----- Logistic Regression -----
# Accuracy: 0.9524663677130045
#               precision    recall  f1-score   support
#
#          ham       0.95      1.00      0.97       965
#         spam       0.97      0.67      0.79       150
#
#     accuracy                           0.95      1115
#    macro avg       0.96      0.83      0.88      1115
# weighted avg       0.95      0.95      0.95      1115
#
#
# ----- SVM -----
# Accuracy: 0.9766816143497757
#               precision    recall  f1-score   support
#
#          ham       0.97      1.00      0.99       965
# ...

# %%
print("\nConfusion Matrix (Naive Bayes):")
print(confusion_matrix(y_test, y_pred_nb))
# Out:
# Confusion Matrix (Naive Bayes):
# [[965   0]
#  [ 37 113]]

# %%
sample = ["Congratulations! You won a free ticket"]
sample_tfidf = tfidf.transform(sample)

print("Prediction:", nb.predict(sample_tfidf))
# Out:
# Prediction: ['ham']

# %%
import re

def clean_text(text):
    text = text.lower()
    text = re.sub(r'[^a-zA-Z]', ' ', text)
    return text

df['message'] = df['message'].apply(clean_text)

# %%
tfidf = TfidfVectorizer(
    stop_words='english',
    ngram_range=(1,2),   # unigrams + bigrams
    max_features=3000
)
X_train_tfidf = tfidf.fit_transform(X_train)
X_test_tfidf = tfidf.transform(X_test)

# %%
nb = MultinomialNB()
nb.fit(X_train_tfidf, y_train)
y_pred_nb = nb.predict(X_test_tfidf)

lr = LogisticRegression()
lr.fit(X_train_tfidf, y_train)
y_pred_lr = lr.predict(X_test_tfidf)

svm = SVC()
svm.fit(X_train_tfidf, y_train)
y_pred_svm = svm.predict(X_test_tfidf)

# %%
sample = ["Win cash now!!!"]
sample_clean = clean_text(sample[0])
sample_vec = tfidf.transform([sample_clean])

print(nb.predict(sample_vec))
# Out:
# ['spam']

# %%
from sklearn.metrics import roc_auc_score
import numpy as np

# Ensure y_test is numeric (0 for 'ham', 1 for 'spam')
y_test_numeric = y_test.map({'ham': 0, 'spam': 1})

# Ensure y_pred_nb is numeric (0 for 'ham', 1 for 'spam')
y_pred_nb_numeric = np.where(y_pred_nb == 'ham', 0, 1)

print("ROC-AUC (Naive Bayes):", roc_auc_score(y_test_numeric, y_pred_nb_numeric))
# Out:
# ROC-AUC (Naive Bayes): 0.8766666666666667

# %%
from sklearn.metrics import roc_auc_score
import numpy as np

# Ensure y_test is numeric (0 for 'ham', 1 for 'spam')
y_test_numeric = y_test.map({'ham': 0, 'spam': 1})

# Ensure y_pred_nb is numeric (0 for 'ham', 1 for 'spam')
y_pred_nb_numeric = np.where(y_pred_nb == 'ham', 0, 1)

print("ROC-AUC:", roc_auc_score(y_test_numeric, y_pred_nb_numeric))
# Out:
# ROC-AUC: 0.8766666666666667

# %%
sample = ["Win cash now!!!"]
sample_clean = clean_text(sample[0])
sample_vec = tfidf.transform([sample_clean])

print(nb.predict(sample_vec))
# Out:
# ['spam']

# %%
import joblib

joblib.dump(nb, 'spam_model.pkl')
joblib.dump(tfidf, 'vectorizer.pkl')
# Out:
# ['vectorizer.pkl']
